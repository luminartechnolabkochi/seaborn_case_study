# %%
! pip install seaborn
! pip install numpy pandas
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for numpy!=1.24.0,>=1.20 from https://files.pythonhosted.org/packages/8c/de/f5e79650d23d9e12f38a7bc6b03ea0835b9575494f8ec94c11c6e773b1b1/numpy-2.4.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pandas>=1.2 from https://files.pythonhosted.org/packages/51/27/bf9436dd0a4fc3130acec0828951c7ef96a0631969613a9a35744baf27f6/pandas-3.0.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for matplotlib!=3.6.1,>=3.4 from https://files.pythonhosted.org/packages/6f/d3/a4bbc01c237ab710a1f22b4da72f4ff6d77eb4c7735ea9811a94ae239067/matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
# ...

# %%
! pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# amqp                          5.1.1
# asgiref                       3.6.0
# asttokens                     3.0.1
# Babel                         2.12.1
# billiard                      3.6.4.0
# boto3                         1.26.77
# botocore                      1.29.77
# celery                        5.2.7
# certifi                       2022.12.7
# cffi                          1.15.1
# charset-normalizer            3.0.1
# click                         8.1.3
# click-didyoumean              0.3.0
# click-plugins                 1.1.1
# click-repl                    0.2.0
# colorama                      0.4.6
# comm                          0.2.3
# cryptography                  41.0.1
# debugpy                       1.8.19
# decorator                     5.2.1
# distlib                       0.3.8
# Django                        4.1.6
# django-celery-beat            2.4.0
# ...

# %% [markdown]
# seaborn comes with default dataset
# for listing data set available in seaborn

# %% [markdown]
# sns.get_dataset_names()

# %%
import seaborn as sns

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins=sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='str')

# %%
penguins["species"].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
#scatter plot
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g")
# in the scatter plot we can conclude as flipper length increases body mass also increases
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#scatter plot with hue [group by ]
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="island")
# from this plot we can understand biscoe island penguine with high flipper length and bodymass
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#scatter plot with hue [group by sex ]
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="sex")
# from this plot we can understand male penguine with high flipper length and bodymass
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#sns.despine() remove top and right bar
#sn.despine(left=True) remove left
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="sex")
sns.despine()
# from this plot we can understand male penguine with high flipper length and bodymass

# %%
#set_style and set_context
sns.set_style("darkgrid")#'white', 'dark', 'whitegrid', 'darkgrid', 'ticks' => grid color
sns.set_context("notebook") #'paper', 'notebook', 'talk', 'poster' => chart size
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(data=penguins,x="flipper_length_mm",y="body_mass_g",hue="sex",palette="dark")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
#strip plot

sns.stripplot(data=penguins,x="species",y="body_mass_g",hue="island",dodge=True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#swarm plot
sns.set_context("talk")

sns.swarmplot(data=penguins,x="island",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
#histogram

sns.set_context("notebook")

sns.histplot(data=penguins,x="body_mass_g")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
sns.set_context("notebook")

sns.histplot(data=penguins,x="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
#regression plot fits a regression line

sns.regplot(data=penguins,x="body_mass_g",y="flipper_length_mm",color="green")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
#line plot
sns.lineplot(data=penguins,x="body_mass_g",y="flipper_length_mm")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.lineplot(data=penguins,x="body_mass_g",y="flipper_length_mm",hue="sex")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
#bar plot
sns.barplot(data=penguins,x="species",y="body_mass_g",hue="sex",palette=["pink","skyblue"])
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
import numpy as np
sns.barplot(data=penguins,x="species",y="body_mass_g",hue="sex",palette=["pink","skyblue"],estimator=np.sum)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#count plot

sns.countplot(data=penguins,x="species",hue="island",palette="Set2")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
#box plot
sns.set_context("paper")
sns.boxplot(data=penguins,x="species",y="body_mass_g",hue="island")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.set_context("paper")
sns.boxplot(data=penguins,x="species",y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#voilin plot
sns.violinplot(data=penguins,x="species",y="body_mass_g",hue="sex")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#voilin plot
sns.violinplot(data=penguins,x="species",y="body_mass_g",hue="sex",split=True)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
#kde(kernal desnsity estimation) like histogram

sns.kdeplot(data=penguins,x="body_mass_g",hue="species",fill=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
#heat map => correlation works with numerical columns
penguins.head()
columns=["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]
penguins[columns].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(data=penguins[columns].corr(),annot=True,cmap="coolwarm")
# annot=True annotate value
# cmap="Blues"
