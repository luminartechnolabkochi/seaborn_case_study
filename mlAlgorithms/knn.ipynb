# %% [markdown]
# 🤖 What is Machine Learning?
#
# Machine Learning (ML) is a branch of Artificial Intelligence (AI) where computers learn from data and make decisions or predictions without being explicitly programmed for every case.
#
# 👉 Instead of writing rules manually, we give data + examples, and the machine finds patterns.
#
# Simple example:
#
#     You show a system 1000 emails
#
#     Some are labeled Spam, some Not Spam
#
#     The system learns the pattern
#
#     Next time, it can automatically detect spam

# %% [markdown]
#         🔁 Steps Involved in Machine Learning
#
# 1️⃣ Problem Definition
#
# What are you trying to solve?
#
# Predict price?
#
# Classify spam?
#
# Recommend products?
#
# 📌 Example: Predict house price
#
#
# 2️⃣ Data Collection
#
# Collect data from:
#
# CSV files
#
# Databases
#
# APIs
#
# Sensors
# 📌 Example: house size, location, rooms, price
#
#
# 3️⃣ Data Cleaning (Very Important ❗)
#
# Handle:
#
# Missing values
#
# Duplicate data
#
# Outliers
#
# Wrong data types
#
# 📌 Example: empty price values, incorrect ages
#
#
# 4️⃣ Exploratory Data Analysis (EDA)
#
# Understand data using:
#
# Charts
#
# Statistics
#
# Correlation
#
# 📌 Example:
#
# Does size affect price?
#
# Is location important?
#
# 5️⃣ Feature Engineering
#
# Select or create useful inputs (features)
#
# Remove unnecessary columns
#
# 📌 Example:
#
# Convert “location” to numbers
#
# Create price_per_sqft
#
#
# 6️⃣ Split the Data
#
# Training Data → model learns
#
# Testing Data → model is evaluated
#
# Typical split:
#
# 80% Train
#
# 20% Test
#
#
# 7️⃣ Choose the ML Algorithm
#
# Depends on problem type
#
# Regression
#
# Classification
#
# Clustering
#
# 8️⃣ Train the Model
#
# Feed training data to the algorithm
#
# Model learns patterns
#
# 9️⃣ Evaluate the Model
#
# Check performance using metrics:
#
# Accuracy
#
# Precision
#
# Recall
#
# RMSE
